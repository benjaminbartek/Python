# %%
#Imports
import locale

#Globals

kids_price = 3.79
burger_price = 1.25
chzburger_price = 1.50
chicken_sand_price = 3.25
chicken_nug_price = 3.25
salad_price = 3.50
fries_price = 1.15
onion_ring_price = 1.20
milk_price= 3.39
coke_price = 2.29

Foods = ['Kids Meal', 'Hamburger', 'Cheeseburger', 'Chicken Sandwich', 'Chicken Nuggets', 'Salad', 'Fries', 'Onion Rings', 'Milkshake', 'Coke']
Prices = [3.79, 1.25, 1.50, 3.25, 3.25, 3.50, 1.15, 1.20, 3.39, 2.29]
menu_dict = dict(zip(Foods, Prices))

cart = {}

#Class
class color:
    bold = '\033[1m'
    end = '\033[0m'


class CashRegister:
    
    def __init__(self):
        #self.whatthefuckshouldgohere
    
    def addItem(self, price):
        fart = int(input('fuck me in the goat ass i hate this class. how many foods to you fucking want?'))
        cart.append(fart)
        #Keeps track of items in cart
        
    def getTotal(self):
        for key, val in cart:
            totalPrice = sum(key * val)
        return totalPrice #format as currency
    
    def getCount(self):
        
        return itemCount
        
        

#Standalone Functions
def Welcome():
    welcome_msg = (color.bold + 'Welcome To DSC 510 Cash Register!' + color.end)
    print(welcome_msg.center(117))
    
def Quit():
    quit_msg = (color.bold + 'GOOD BYE!' + color.end)
    print('\n\n')
    print(quit_msg.center(117))
    
def main_options():
    print('Please select from the following options:\n\n1. )
    
def main():
    welcome_msg()
    while True:
        print('Please select from the following items:\n')
        print('0. Kids Meal\n1. Hamburger\n2. Cheeseburger\n3. Chicken Sandwich\n4. Chicken Nuggets\n5. Salad\n6. Fries\n7. Onion Rings\n8. Milkshake\n9. Coke\n\n')#Add Item Loop Until Quit
        loadFood = input('Select 0-9 OR 99 to cash out:')
        if loadFood == '0':
            kids_count = int(input('How Many? '))
            addItem(self, kids_price)
            continue
        elif loadFood == '1':
            burger_count = int(input('How Many? '))
            addItem(self, burger_price)
            continue
        elif loadFood == '2':
            cheez_count = int(input('How Many? '))
            addItem(self, chzburger_price)
            continue
        elif loadFood == '3':
            sand_count = int(input('How Many? '))
            addItem(self, chicken_sand_price)
            continue
        elif loadFood == '4':
            nugg_count = int(input('How Many? '))
            continue
        elif loadFood == '5':
            salad_count = int(input('How Many? ')) 
            continue
        elif loadFood == '6':
            fries_count = int(input('How Many? '))
            continue
        elif loadFood == '7':
            onion_count = int(input('How Many? '))
            continue
        elif loadFood == '8':
            milk_count = int(input('How Many? '))
            continue
        elif loadFood == '9':
            coke_count = int(input('How Many? '))
            continue
        elif loadFood == '99':
            getTotal()
            break
                    
    
#Main Program
main()
# Out:
#   File "<ipython-input-11-c39c4441e51f>", line 30
#     def getTotal():
#       ^
# IndentationError: expected an indented block

# %%
#Class
class color:
    bold = '\033[1m'
    end = '\033[0m'

def Welcome():
    welcome_msg = (color.bold + 'Welcome To DSC 510 Cash Register!' + color.end)
    print(welcome_msg.center(117))

def main():
    Welcome()
    while True:
        print('Please select from the following items:\n')
        print('0. Kids Meal\n1. Hamburger\n2. Cheeseburger\n3. Chicken Sandwich\n4. Chicken Nuggets\n5. Salad\n6. Fries\n7. Onion Rings\n8. Milkshake\n9. Coke\n\n')#Add Item Loop Until Quit
        loadFood = input('Select 0-9 OR 99 to cash out:')
        if loadFood == '0':
            kids_count = int(input('How Many? '))
            continue
        elif loadFood == '1':
            burger_count = int(input('How Many? '))
            continue
        elif loadFood == '2':
            cheez_count = int(input('How Many? '))
            continue
        elif loadFood == '3':
            sand_count = int(input('How Many? '))
            continue
        elif loadFood == '4':
            nugg_count = int(input('How Many? '))
            continue
        elif loadFood == '5':
            salad_count = int(input('How Many? ')) 
            continue
        elif loadFood == '6':
            fries_count = int(input('How Many? '))
            continue
        elif loadFood == '7':
            onion_count = int(input('How Many? '))
            continue
        elif loadFood == '8':
            milk_count = int(input('How Many? '))
            continue
        elif loadFood == '9':
            coke_count = int(input('How Many? '))
            continue
        elif loadFood == '99':
            getTotal()
            break
                    
    
#Main Program
main()
# Out:
#                                       Welcome To DSC 510 Cash Register!
# Please select from the following items:
#
# 0. Kids Meal
# 1. Hamburger
# 2. Cheeseburger
# 3. Chicken Sandwich
# 4. Chicken Nuggets
# 5. Salad
# 6. Fries
# 7. Onion Rings
# 8. Milkshake
# 9. Coke
#
#
# Select 0-9 OR 99 to cash out:0
# How Many? 2
# Please select from the following items:
#
# 0. Kids Meal
# 1. Hamburger
# 2. Cheeseburger
# 3. Chicken Sandwich
# 4. Chicken Nuggets
# 5. Salad
# 6. Fries
# 7. Onion Rings
# 8. Milkshake
# 9. Coke
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# ...

# %%
Foods = ['Kids Meal', 'Hamburger', 'Cheeseburger', 'Chicken Sandwich', 'Chicken Nuggets', 'Salad', 'Fries', 'Onion Rings', 'Milkshake', 'Coke']
Prices = [3.79, 1.25, 1.50, 3.25, 3.25, 3.50, 1.15, 1.20, 3.39, 2.29]
cart = dict(zip(Foods, Prices))
print(cart)
# Out:
# {'Kids Meal': 3.79, 'Hamburger': 1.25, 'Cheeseburger': 1.5, 'Chicken Sandwich': 3.25, 'Chicken Nuggets': 3.25, 'Salad': 3.5, 'Fries': 1.15, 'Onion Rings': 1.2, 'Milkshake': 3.39, 'Coke': 2.29}
